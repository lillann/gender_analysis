# %%
import pandas as pd
import sys
import numpy as np

path_to_data = "/Users/annl/Desktop/GenieProjekt/jobads/"

# Remove "tillkännagivanden" and duplicate ads
forbidden_strings = 'tillkänn|tillsätt|beslut'

def remove_non_ads(df) :
    df = df[~(df['variant_name'].str.lower().str.contains(forbidden_strings,na = False))]
    df = df[~(df['prefix_text'].str.lower().str.contains(forbidden_strings,na = False))]  
    df = df.drop_duplicates(subset='text')
    df = df.reset_index(drop=True)
    return df

def prepare_dataframe(file) : 
    df = remove_non_ads(pd.read_csv(path_to_data + file))
    return df

df_ltu_en = prepare_dataframe("jobads_ltu_en.csv")
df_ch_en  = prepare_dataframe("jobads_ch_en.csv")
df_gu_en  = prepare_dataframe("jobads_gu_en.csv")
df_ltu_sv = prepare_dataframe("jobads_ltu_sv.csv")
df_ch_sv  = prepare_dataframe("jobads_ch_sv.csv")
df_gu_sv  = prepare_dataframe("jobads_gu_sv.csv")

# %%
# pair Swedish and English ads based on project identifier

cols = ['project_id','id','text']

def merge_on_id(df1,df2) :
  
    df = pd.merge(df1[cols],df2[cols], on = "project_id")
    df = df.drop_duplicates(subset='text_x')
    df = df.drop_duplicates(subset='id_y').reset_index()
    return df

ch_merged       = merge_on_id(df_ch_sv,df_ch_en)
ltu_merged      = merge_on_id(df_ltu_sv,df_ltu_en)
gu_merged       = merge_on_id(df_gu_sv,df_gu_en)

all_merged = ltu_merged.append(ch_merged.append(gu_merged))

# All english ads with a Swedish equivalent
df_en_all = all_merged['text_y'].reset_index()

# All Swedish ads with an english equivalent
df_sv_all = all_merged['text_x'].reset_index()

# %%
from nltk.translate import gale_church
from nltk import sent_tokenize

# Splits the swedish and english texts into sentences and 
# aligns them according to the gale church algorithm, to get pairs of 
# sentences that are translations of each other.
def align_sentences(text_swe,text_eng) : 
    
    sents_swe = sent_tokenize(text_swe)
    sents_eng = sent_tokenize(text_eng)
    
    # splitting into paragraphs first makes the splits more fine-grained
    paragraphs1 = [p for p in text_swe.split('\n') if p]
    paragraphs2 = [p for p in text_eng.split('\n') if p]

    sents1 = []
    sents2 = []
    for p in paragraphs1 :
        sents = sent_tokenize(p)
        sents1 = sents1 + sents
    for p in paragraphs2 :
        sents = sent_tokenize(p)
        sents2 = sents2 + sents

    lengths_swe = [len(s) for s in sents1]
    lengths_eng = [len(s) for s in sents2]

    alignment_indices = gale_church.align_blocks(lengths_swe,lengths_eng)
    alignment = ([(sents1[i],sents2[j]) for (i,j) in alignment_indices])     
    return alignment

# %%
# Aligned sentences of each Swedish-English text pair
aligned_texts = [align_sentences(df_sv_all.iloc[i]['text_x'],
                                 df_en_all.iloc[i]['text_y']) 
                 for i in range(len(df_sv_all))]

# %%
import sys
sys.path.append('../')
from genderdecoder import assess


assessments_all = [ assess(eng) for eng in df_en_all['text_y'].values]
                  
# All gendered words that occur in the English texts
coded_words_ = [ 
                ass['masculine_coded_words'] + 
                ass['feminine_coded_words']  
                for ass in (assessments_all)]

coded_words = list(set([ w for ls in coded_words_ for w in ls ]))

# All aligned sentences that contain an English gendered word
filtered_aligned_texts = [(swe,eng) for texts in aligned_texts 
                          for (swe,eng) in texts 
                              if any([coded_word in eng 
                                for coded_word in coded_words])  
                         ]

# %%
coded_words
# Out:
# ['collaboration/program',
#  'defend',
#  'persistent',
#  'agreement',
#  'nurturing',
#  'dominated',
#  'persistence',
#  'logic',
#  'dependability',
#  'supportive',
#  'co-operate',
#  'shares',
#  'leadership',
#  'sharing',
#  'cooperate',
#  'courage',
#  'collaboratively',
#  'enthusiastically',
#  'commitment',
#  'understandable',
#  'independently/individually',
#  'compete',
#  'competitiveness',
#  'leading',
#  'responsibility',
#  'cooperating',
#  'decides',
#  'self-confident',
#  'cooperative',
#  'actively',
#  'competitive',
#  'superior',
#  'active',
#  'leaderships',
#  'intellectual',
#  'collaborate',
#  'determined',
#  'connection',
#  'collaborations',
#  'yield',
#  'dominating',
#  'children',
#  'emotional',
#  'sensitivity',
#  'dependent',
#  'challenges',
#  'responsi',
#  'analyse',
#  'determining',
#  'intellect',
#  'decision',
#  'enthusiastic',
#  'collaborates',
#  'dominates',
#  'objectives',
#  'ambitious',
#  'kindly',
#  'collaborator',
#  'analyses',
#  'autonomy',
#  'competences',
#  'cooperates',
#  'kinds',
#  'determination',
#  'competition',
#  'understanding',
#  'defended',
#  'leaders',
#  'depending',
#  'dependable',
#  'competencies',
#  'collab-oration',
#  'sensitive',
#  'challenged',
#  'challenging',
#  'understand',
#  'committed',
#  'analysis',
#  'autonomous',
#  'dependence',
#  'decisive',
#  'feelings',
#  'analysts',
#  'collaboration',
#  'child',
#  'forces',
#  'objective',
#  'analytical',
#  'commitments',
#  'analytics',
#  'agrees',
#  'support',
#  'agreements',
#  'objectively',
#  'analyze',
#  'interpersonal',
#  'analytic',
#  'force',
#  'kind',
#  'opinion',
#  'autonomously',
#  'together',
#  'responsible',
#  'competing',
#  'trust',
#  'competency',
#  'determine',
#  'analysing',
#  'analyzing',
#  'inclusive',
#  'individuals',
#  'co-operatively',
#  'analyzes',
#  'cooperation',
#  'ambition',
#  'individual',
#  'responding',
#  'determinants',
#  'pleasant',
#  'dominant',
#  'competitions',
#  'connecting',
#  'independency',
#  'independence',
#  'lead',
#  'leader',
#  'individually',
#  'decisions',
#  'committee',
#  'collaborative',
#  'responsibilities',
#  'connect',
#  'principles',
#  'shared',
#  'supported',
#  'share',
#  'connectivity',
#  'hierarchical',
#  'responibilities',
#  'response',
#  'independently',
#  'decision-making',
#  'agreed',
#  'challeng-es',
#  'respond',
#  'connected',
#  'principle',
#  'co-operation',
#  'decision-makers',
#  'competent',
#  'confident',
#  'collaborators',
#  'driven',
#  'collaboration/',
#  'cooperations',
#  'trustworthy',
#  'warm',
#  'competence',
#  'ambitions',
#  'analysed',
#  'depends',
#  'leads',
#  'analytically',
#  'independent',
#  'co-operations',
#  'analyzed',
#  'feel',
#  'collaborating',
#  'decided',
#  'depend',
#  'individual/passenger',
#  'autonomic',
#  'responses',
#  'challenge',
#  'supporting',
#  'supports',
#  'connections']

# %%
import unicodedata
import re

# All words occuring in the Swedish ads
all_swedish_words_ = [re.findall('[\wöåä\-]+', text, flags=re.UNICODE+re.IGNORECASE) 
                        for (text,eng) in filtered_aligned_texts]
all_swedish_words  = list(set([w.lower() for ws in all_swedish_words_ for w in ws]))

# %%
all_swedish_words
# Out:
# ['forsknings-',
#  'framförallt',
#  'främst',
#  'bärförmågan',
#  'supportsystem',
#  'bakom',
#  'fysisk',
#  'militära',
#  'designprocesser',
#  'statsvetenskap',
#  'ökade',
#  'frågor',
#  'utmaningarna',
#  'masteruppsatser',
#  'företagsekonomiskt',
#  'amminex',
#  'beredskapskritiska',
#  'värdeutbyte',
#  'licentiand',
#  '2013',
#  'het',
#  'samverkansprocesser',
#  'höggenomströmningsdata',
#  'önskemål',
#  'ges',
#  'publik',
#  'kallt',
#  'kursutveckling',
#  'differentiering',
#  'boliden',
#  'energivetenskap',
#  'exjobb',
#  'smörjsystem',
#  'distributionsnät',
#  'efterbehandling',
#  '-metoder',
#  'sulfidmineraliseringar',
#  'steg',
#  'föreskrifterna',
#  'fernandez-rodriguez',
#  '0911-72618',
#  'bildanalysalgoritmer',
#  'hyperspektrala',
#  'drivkraft',
#  'väggar',
#  'sökande',
#  'dynamik',
#  'motor-',
#  'multiple',
#  'visa',
#  'djupinlärning',
#  'riktar',
#  'bostadssituation',
#  'examinerats',
#  'biokemisk',
#  'fluid-struktur',
#  'bortforsling',
#  'värmeåtervinning',
#  'fall',
#  'utmana',
#  'variablernas',
#  'båt',
#  'carlberg',
#  'kvalitativa',
#  'strukturell',
#  'kartografisk',
#  'nyckelperson',
#  'generative',
#  'inriktat',
#  'stark',
#  'strukturgeologi',
#  'eunderhåll',
#  'msc',
#  'elitensembler',
#  'utbildningsverksamheten',
#  'datarika',
#  'positionen',
#  'analysis',
#  'jordar',
#  'inledande',
#  'bakgrund',
#  'fysikens',
#  'gov',
#  'f',
#  'sammarbete',
#  'immateriella',
#  'övningsmiljö',
#  'dok',
#  'strukturgeologiska',
#  'termer',
#  'redan',
#  'agenter',
#  'grundvattenprovtagning',
#  'elgenerering',
#  'forskningsutmaningar',
#  'avser',
#  'riksbankens',
#  'juli',
#  'förgasningsteknik',
#  'förtrogenhet',
#  'epoxilimmade',
#  'vindkraft',
#  'immunologi',
#  'absorptionslinjerna',
#  'drift',
#  'strategiskt',
#  'sammarbeta',
#  'domineras',
#  'bioinformatics',
#  'fördjupade',
#  'utreder',
#  'erhållit',
#  'prioriterade',
#  'avfallsproblem',
#  'kalla',
#  'maskinelementgruppen',
#  'hjälpmedel',
#  'jordfelsskydd',
#  'störa',
#  'uppfattar',
#  'aktuator-system',
#  'egenskapsbestämning',
#  'bilddata',
#  'händelse',
#  'bildbehandling',
#  'sakliga',
#  'pilotskaleförgasare',
#  'beräkningssystem',
#  'energitillämpningar',
#  'com',
#  'sändareffekt',
#  'tillgång',
#  'avsedd',
#  'nätverksmedicin',
#  'tillvägagångssättet',
#  'komplement',
#  'smältpunkt',
#  'ltus',
#  'qc',
#  'vattenkraftsanläggningar',
#  'konsortium',
#  'tekniklektor',
#  'existerar',
#  'gruvor',
#  'lämnats',
#  'fjärranalysområdet',
#  'metallinehåll',
#  '920-493880',
#  'konstruktionen',
#  'logistik',
#  'brandingenjörsprogrammet',
#  'forskningsämnena',
#  'prefektrekryteringar',
#  'kit',
#  'part',
#  'dataintegration',
#  'månadslön',
#  'guld-koppar-zink',
#  'bundna',
#  'bestämningsfaktorer',
#  'svenska',
#  'swot-analys',
#  'habitability',
#  'studerar',
#  'dokumenterad',
#  'skickliga',
#  'rymdanknutna',
#  'fraunhofer',
#  'införandefrågor',
#  'mpc',
#  'cell',
#  'ultraljud',
#  'konkurrenskraftig',
#  'servoing',
#  'lågspänningsnätet',
#  'beslut',
#  'dissemination',
#  'miljöpåverkan',
#  'nordiska',
#  'didaktisk',
#  'profilområdet',
#  'värdeskapande',
#  'sektionen',
#  'webbsidan',
#  'städerna',
#  'internetanslutna',
#  'utgångpunkt',
#  'industrialiserade',
#  'laboratory',
#  'minimera',
#  'ta',
#  'handleder',
#  'byta',
#  'beskrivs',
#  'linje',
#  'testning',
#  'avslutats',
#  'kulsinter-',
#  'forskarskolan',
#  'profilområden',
#  'tolkningsverktyg',
#  'möta',
#  'pdf-filer',
#  'huruvida',
#  'containrar',
#  'kvantifiering',
#  'forskargruppen',
#  'variation',
#  'marktemperatursensor',
#  'intressenter',
#  'gång',
#  'xiaoyan',
#  'åtkomst',
#  'volymen',
#  'harmoniska',
#  'org',
#  'numerisk',
#  'empiri',
#  'pågående',
#  'virtual',
#  'sjöfart',
#  'uppfyllda',
#  'raketflygdynamik',
#  'baseras',
#  'next',
#  'bim',
#  'finansieringsaktiviteter',
#  'testa',
#  'presenterade',
#  'dokumentbehandling',
#  'underrepresenterade',
#  'managing',
#  'industriparter',
#  'expandering',
#  'miljöförbättrande',
#  'göra',
#  'extraktionskromatografi',
#  'ramen',
#  'turbinen',
#  'själv',
#  'forskarnivå',
#  'genomgripande',
#  'idag',
#  'bildats',
#  'skapas',
#  'delsystem',
#  'labs',
#  'positioner',
#  'tekniklektorer',
#  'driftstopp',
#  'on',
#  'humanstudier',
#  'bygg-',
#  'serie',
#  'materialoptimering',
#  'programutvecklingskoncept',
#  'nationaliteter',
#  'wallenberg',
#  'prehospital',
#  'utgöra',
#  'teknologiska',
#  'elektrokemi',
#  'jobb',
#  'eu-program',
#  'reglerteknik-teamet',
#  'resans',
#  'innovationsprocess',
#  'undervisningen',
#  'lom',
#  'högpresterande',
#  '17',
#  'konstruktionsprocessen',
#  'bodin',
#  'hela',
#  'förenklingar',
#  'organisatoriskt',
#  'partikelstorleksanalys',
#  'därigenom',
#  'byggnader',
#  'toronto',
#  'skadehändelser',
#  'moleylärbiologisk',
#  'trådlösa',
#  'gasflöden',
#  'gruvbolaget',
#  'kvaliteter',
#  'vattenkraftsindustri',
#  'sättas',
#  '50-100',
#  'naturlig',
#  'passiva',
#  'finnas',
#  'filmdesign',
#  'magnetoreologiskt',
#  'viktig',
#  'nätverkskommunikation',
#  'kromatografi',
#  'förändringsmodeller',
#  'eldistributionsnät',
#  'institutes',
#  'spraakbanken',
#  'livslängd',
#  'sos',
#  'cement',
#  'energiförbrukande',
#  'yrkesskicklighet',
#  'robotik',
#  'samarbetande',
#  'tfn',
#  'akustik',
#  'nolltryck',
#  'sina',
#  'planeringsteori',
#  'hyvleri',
#  'annonserade',
#  'masterprogam',
#  'zeolitsyntes',
#  'separera',
#  'feldiagnostik',
#  'bioenergikombinat',
#  'komplett',
#  'computer',
#  'tidiga',
#  'löslighet',
#  'slutföra',
#  'åsa',
#  'kursansvar',
#  'bostadsbristen',
#  'texter',
#  'företrädarna',
#  'beslutsstöden',
#  'avgörs',
#  'kognitiva',
#  'smältprocessen',
#  'forskningsråd',
#  'sotl',
#  'extrema',
#  '2002',
#  'schema',
#  'energilager',
#  'nedströmsprocesser',
#  '35',
#  'samstämmig',
#  'ekonometriker',
#  'aspx',
#  'knuten',
#  'karlstads',
#  'påvisad',
#  'förutsebara',
#  'katalytisk',
#  'magisternivå',
#  'verktygsprototyper',
#  'ultrarena',
#  'with',
#  'behörighet',
#  'stadsbyggnadsforskning',
#  'utav',
#  'detaljer',
#  'planeringsprocesser',
#  'inre',
#  'relaterat',
#  'utvecklingsmiljöer',
#  'mag-tarmkanalen',
#  'svaj',
#  'miljö-',
#  'laborations-',
#  'möjlighet',
#  'relationen',
#  'metrologiska',
#  'analytiska',
#  'division',
#  'elektronikproduktion',
#  'utvecklings-',
#  'stiftelser',
#  'lagerstyrning',
#  'sprida',
#  'malningstester',
#  'augusti',
#  'modelleringsspråk',
#  'adresserar',
#  'undervisningsmiljön',
#  'specifikation',
#  'reaktorerna',
#  'sett',
#  'radiovågor',
#  'mån',
#  'spänner',
#  'involverad',
#  'originell',
#  'jullander',
#  'engagerad',
#  'samarbetsmöjligheterna',
#  'organisationerna',
#  'knyta',
#  'elektrolyterna',
#  'attraktiv',
#  'close',
#  'integration',
#  'branscher',
#  'applicerat',
#  'forskningsuppgifter',
#  'regional',
#  'undermarksinformation',
#  'utbildningar',
#  'avdelningarna',
#  'høgskolen',
#  'gränssnittet',
#  '2040',
#  'tydligt',
#  'världsomspännande',
#  'viskoelastisk',
#  'fackspråkliga',
#  'krav',
#  'mineralprospekteringsbolaget',
#  'sättet',
#  'strukturerna',
#  'nyckelkompetenser',
#  'reaktionssystem',
#  'dsi-forskning',
#  'vinnväxt-vinnaren',
#  'tillverkning',
#  'älvbäddar',
#  'bildades',
#  'delsing',
#  'aktuatorer',
#  'kraftvärme',
#  'naturvetenskapligt',
#  'teknikerna',
#  'inrättas',
#  'masterutbildningarna',
#  'mineralprocesser',
#  'stadens',
#  'vetenskapsrådet',
#  'driften',
#  'konceptet',
#  'biobränsleanvändning',
#  'batteriprestanda',
#  'multi-robot',
#  'enklaste',
#  'någon',
#  'digitaliseringstjänster',
#  'beräkningsmetoder',
#  'utct',
#  'upplysningar',
#  'passa',
#  'hjärndataanalys',
#  'robotiserade',
#  'vårt',
#  'bioplast',
#  'tidigast',
#  'fukthalt',
#  'detonikförsök',
#  'flesta',
#  'forskargruppsledare',
#  'vidare-utvecklingen',
#  'prioritet',
#  'forskningsmedel',
#  'ansedda',
#  'röntgenbaserad',
#  'viii',
#  'konstnärligt',
#  'nummer',
#  'kompe',
#  '491298',
#  'nudging',
#  'regel',
#  'stadsrummens',
#  'licentiatseminarium',
#  'norrbottenområdet',
#  'huvudsyftet',
#  'svälla',
#  'bredden',
#  'bifogar',
#  'skickligheten',
#  'forskningsverksamheten',
#  'musikpedagogik',
#  'forskarsamhället',
#  'sceniskt',
#  'synliggör',
#  'datatyper',
#  'prediktera',
#  'prospekteringsteknologier',
#  'strålning',
#  'saltning',
#  'miljögifter',
#  'kraftkvalitet',
#  'sv',
#  'säljbolag',
#  'nvh-aspekter',
#  'bioproteser',
#  'hearts',
#  '-design',
#  'hyllad',
#  'diffraktiva',
#  'ståltorn',
#  'karaktärisera',
#  'ljusmodellerare',
#  'fysikalisk-kemiska',
#  'sub-t',
#  'grundläggande',
#  'genusvetenskaplig',
#  'avloppsreningsverk',
#  'synsätt',
#  'väg-',
#  'beslutsproblem',
#  'infraröd',
#  'driftsutrustning',
#  'resurs',
#  'workshops',
#  'usa',
#  'olinjära',
#  'jord',
#  'hårda',
#  'kommun',
#  'temperaturfördelningen',
#  'forskarstudierna',
#  'koordinator',
#  'nonlinear',
#  'tryckmätningar',
#  'dimensionera',
#  'inriktningar',
#  'koppla',
#  'förutspås',
#  'traditionellt',
#  'korrekt',
#  'stå',
#  'sönderdelnings-',
#  'u4iot',
#  'tillämpa',
#  'fourieranalys',
#  'bild',
#  'icke-lte',
#  'deltagande',
#  'datamängder',
#  'adsorptionsmaterial',
#  'hemvist',
#  'storskaliga',
#  'redovisa',
#  'liknande',
#  'forskningssamarbetet',
#  'människa-datorinteraktion',
#  'projektkoordinator',
#  'studioresurser',
#  'bioinformatiska',
#  'landsbygds',
#  'tyskland',
#  'kunskapsområde',
#  'anpassas',
#  'ljustemperaturen',
#  'experience',
#  'samarbetsuniversitet',
#  'valet',
#  'funktionalitet',
#  'samlat',
#  'pulverbädd',
#  'förvärvade',
#  'projektet',
#  'slinga',
#  'befordrad',
#  'andel',
#  'resa',
#  'undersökningar',
#  'tumörer',
#  'fas',
#  'exponeringar',
#  'qemscan',
#  'icke-linjäritet',
#  'kurserna',
#  'jobs',
#  'problemet',
#  'ljusintensitet',
#  'urbaniseringen',
#  'cvijoviclab',
#  'stämning',
#  'huvudtillämpningen',
#  'fartygskonstruktion',
#  'sedvanliga',
#  'systemdesign',
#  'nätplanering',
#  'besitter',
#  'nyckelroll',
#  'näringsliv',
#  'nano-cellulosa',
#  'irf',
#  '2014',
#  'polymermatris',
#  'syfte',
#  'typer',
#  'gruvsystemen',
#  'livscykel',
#  'tydliga',
#  'dvs',
#  'befattningens',
#  'dagvattenkvalitet',
#  'data-',
#  'trafik',
#  'styrgrupp',
#  'bränslet',
#  'nordlund',
#  'tyngdkraft',
#  'nivåer',
#  'forskningsmöjligheter',
#  'naturresurser',
#  'begränsade',
#  'ytinstrument',
#  'utbredning',
#  'telekom',
#  'group',
#  'snart',
#  'ruag',
#  'indikationer',
#  'eldrift',
#  'maskinens',
#  'mobilitetsschema',
#  'cooperation',
#  'psykologiskt',
#  'involveras',
#  'universitets',
#  'tel',
#  'träförädling',
#  'markrobotapplikationer',
#  'lösningar',
#  'pelletförbränning',
#  'eislab-avdelningen',
#  'density',
#  'bio-jonvätskor',
#  'inform',
#  'separeras',
#  'metodik',
#  'våg',
#  'straffelement',
#  'artifisiell',
#  'fullskalekonstruktioner',
#  'maktstrukturer',
#  'ramverk',
#  'kring',
#  'stora',
#  'upplevelser',
#  'etablerade',
#  'systemutvecklare',
#  'förhållandet',
#  'prognostisering',
#  'maskininlärningsalgoritmer',
#  'processutveckling',
#  'nanoförstärkningssystem',
#  'nano-baserade',
#  'förslag',
#  'anställningstidens',
#  'frysning',
#  'medianvärde',
#  '0910-58',
#  'anrikning',
#  'hong',
#  'dagvattnets',
#  'aktuell',
#  '30',
#  'uppkommer',
#  'teknologier',
#  'klarinettisten',
#  'gruvföretaget',
#  'uppbyggd',
#  'affärsutveckling',
#  'basmetallernas',
#  'förgasning',
#  'färdig',
#  'doktorandernas',
#  'osäkerhetsuppskattning',
#  'inductively',
#  'uppskattar',
#  'masterprogram',
#  'kiruna',
#  'jonbyteskromatografi',
#  'infrastrukturkomponenten',
#  'nationella',
#  'rymdkvalificeringen',
#  'bildanalys',
#  'kommuner',
#  'kvalitetsgranskning',
#  'demografiska',
#  'självständiga',
#  'flygfoto',
#  'beslutsfattande',
#  'sanningshalt',
#  'riskgruppsanalys',
#  'ultraljudsbaserad',
#  'polymera',
#  'utbildningsuppdrag',
#  'värdiga',
#  'strålningöverföringsmodellen',
#  'muverdrone-projektet',
#  'beräkningsbaserad',
#  'datorprogram',
#  'kultur',
#  'efter',
#  'laue',
#  'huvudsaklig',
#  'energiproducenter',
#  'träindustrin',
#  'tuffa',
#  'optimization',
#  'människans',
#  'zink-',
#  'läs',
#  'marknadsföringsområdet',
#  'småskaligt',
#  'integrationsaspekter',
#  'utvec',
#  'delvis',
#  'duktig',
#  'säkerhetsprövning',
#  'byggprocessen',
#  'också',
#  'dit135',
#  'spänningsdippmätningar',
#  'säsong',
#  'glatta',
#  'civilrätten',
#  'framkant',
#  'tga-ftir',
#  'eventuellt',
#  'inblandad',
#  'värderas',
#  'atmosfäriska',
#  'agerar',
#  'prospekteringskostnader',
#  'produktionsprocesser',
#  'unika',
#  'siktar',
#  'optimeringsalgoritmer',
#  'utvecklingsprocesser',
#  'stålet',
#  'koefficienter',
#  'utvärdera',
#  'turbinprototypmätningar',
#  'labbförsök',
#  'tech',
#  'medskapande',
#  'kylanordningar',
#  '2017-10-31',
#  'internt',
#  '2030',
#  'plancks',
#  'laboratorieföreståndare',
#  'scholarship',
#  'sedan',
#  'förståeliga',
#  'dimensionslös',
#  'förbättra',
#  'intelligenta',
#  'instruments',
#  'litiumsalter',
#  'trafikanten',
#  'företagsekonomiska',
#  'kännedom',
#  'väst',
#  'minst',
#  'datacenterbyggnader',
#  'tolka',
#  'producenter',
#  'programtransformationer',
#  'flygsäkerhet',
#  'recipient',
#  'egenutvecklade',
#  'stålpulver',
#  'definitivt',
#  'värdegrunder',
#  'goda',
#  'ingenjörsutbildning',
#  'almer',
#  'försäljare',
#  'inriktning',
#  'byggnadsautomation',
#  'h2020-projektet',
#  'leverantörer',
#  '09',
#  'skrivandet',
#  'enlighet',
#  'rigorös',
#  'atmosfären',
#  'mla',
#  'konsumtionsbeteenden',
#  'nanostrukturella',
#  'förvaltningshögskolan',
#  'kommunikationsmässigt',
#  'oförstörande',
#  'praktiker',
#  'insänt',
#  'utbildas',
#  'grönlands',
#  'kognitiv',
#  'uppdelat',
#  'slutlig',
#  'bestämmelser',
#  'gasification',
#  'rättigheter',
#  'representerade',
#  'kemin',
#  'barriärer',
#  'den',
#  'annan',
#  'kontaktytorna',
#  'avloppsvatten',
#  'rekonstruera',
#  'parterna',
#  'överleva',
#  'tem',
#  'innehåll',
#  'biokoksutbytet',
#  'erling',
#  'sentinel-2',
#  'livsvetenskaperna',
#  'omvärlden',
#  'resp',
#  'industrikontakter',
#  'termik',
#  'tilltagande',
#  'kontaktnätverk',
#  'tribologiska-',
#  'universitetssjukhus',
#  'styrkt',
#  'docent',
#  'processindustrier',
#  'kommunicerar',
#  'portföljoptimering',
#  'ämnesöverskridande',
#  'inriktningkurser',
#  'biomatematik',
#  'försöksplanering',
#  'bo',
#  'byggnadsdesign',
#  'gruvprocessen',
#  'mastersutbildningen',
#  'etablering',
#  'programvaru-',
#  'priser',
#  'kopia',
#  'planeternas',
#  'nanosatellit',
#  'ensam',
#  '2017',
#  'estetik',
#  'logistisk',
#  'största',
#  'grate-kiln',
#  'diversifiering',
#  'rektor',
#  'termal',
#  'gas',
#  'geologiska',
#  'snarast',
#  'simuleringspaket',
#  'övergången',
#  'synliga',
#  'verkliga',
#  'anjoner',
#  'civilingenjör-',
#  'länkar',
#  'fou-arbete',
#  'anläggning',
#  'målsättningen',
#  'verktygen',
#  'resursbehov',
#  'demens',
#  'autonomi',
#  'intelligens',
#  'arkitekturgruppen',
#  'vattenbyggnad',
#  'intressant',
#  'järnsvampsprocessen',
#  'miljöavkänning',
#  'objekt',
#  'växel',
#  'regelverken',
#  'producenternas',
#  'bland',
#  'fullerener',
#  'doktorandanställning',
#  'automatiseringsstyrsystem',
#  'initierat',
#  '2010',
#  'bilderna',
#  'försöka',
#  '2021',
#  'vidareutveckling',
#  'sitt',
#  'multi-leder',
#  'frånvaro',
#  'geometri',
#  'stipendiet',
#  'vandringstorkar',
#  'frisk',
#  'projektorienterat',
#  'studieresor',
#  'hushållningen',
#  'projektpartners',
#  'knappen',
#  'teorier',
#  'in-situ-',
#  'morfologisk',
#  'små-',
#  'gynnas',
#  'förtrogen',
#  'korrekthet',
#  'rf',
#  '94',
#  'gåendes',
#  'energisystemproblem',
#  '2017-2021',
#  'förordna',
#  'bodens',
#  'vattenfall',
#  'msc-student',
#  'handlag',
#  'industriföretaget',
#  'klimathotets',
#  'tekniska',
#  'eurowater',
#  'ämnesbeskrivningen',
#  'algebraisk',
#  'användardriven',
#  'intensivt',
#  'lastningskriterier',
#  '2020-10-01',
#  'uttryckets',
#  'återanvändbara',
#  'elektronmikrosond',
#  'partikelanalyser',
#  'samtidiga',
#  'in',
#  'entrepreneurship',
#  'behovsstyrt',
#  'personell',
#  'angreppsättet',
#  'högst',
#  'ohälsa',
#  'tillståndsprocesser',
#  'studera',
#  'banor',
#  'flytande',
#  'astrobiologisk',
#  'vårdnivå',
#  'divisionen',
#  'lager',
#  'elektriskt',
#  'förståeligt',
#  'alme',
#  'landsbygdslandskap',
#  'koncentrera',
#  'förväntat',
#  'environmental',
#  'genomgående',
#  'sjökaptener',
#  'ledningsnätsområdet',
#  'fordonsindustri',
#  'arkitekturområden',
#  'imp',
#  'gruvbrutet',
#  'ekonomikompetens',
#  'ai-lösningar',
#  'byggnadsakustik',
#  'in-ear-monitorer',
#  'finita',
#  'beteendevetenskaperna',
#  'vår',
#  'ugver',
#  'uppdragsutbildningar',
#  'trafiksammanhang',
#  'moped',
#  'nöjet',
#  'satsningen',
#  'elnätet',
#  'forskarlaget',
#  'simulerad',
#  'rymdteknikavdelningen',
#  'principal',
#  'wolfgang',
#  'nr',
#  'spåra',
#  'fallstudie',
#  'så',
#  'transformativa',
#  'återbesättas',
#  'kulturvård',
#  'hydrotermisk',
#  'tunga',
#  'designperspektiv',
#  'prövningen',
#  'forska',
#  'inställning',
#  'samkristaller',
#  'utformad',
#  'företag',
#  'trämaterialets',
#  '920-491792',
#  '400',
#  'boendemiljö',
#  'policys',
#  'kraftindustrin',
#  'technology-related',
#  'radar',
#  ...]

# %%
# Occurrence matrix for all gendered English words over all sentences
occurrence_matrix_docs      = [[text.lower().count(w) for text in ((all_merged['text_y']).tolist())] for w in coded_words]
occurrence_matrix_sentences = [[eng.lower().count(w) for (swe,eng) in filtered_aligned_texts] for w in coded_words]


# Occurrence matrix for all occurring Swedish words over all sentences
occurrence_matrix_docs_sv      = [[text.lower().count(w) for text in ((all_merged['text_x']).tolist())] for w in all_swedish_words]
occurrence_matrix_sentences_sv = [[swe.lower().count(w) for (swe,eng) in filtered_aligned_texts ] 
                                     for w in all_swedish_words]

# %%
from sklearn.metrics.pairwise import cosine_similarity

paired_words = []

# For each gendered word represented in the occurrence matrix,
# find the most similar Swedish word
for i in range (len(occurrence_matrix_sentences)) :
    cos_sims = [cosine_similarity([occurrence_matrix_sentences[i]],occurrence_matrix_sentences_sv)] 
  
    cos_sims = (cos_sims[0].tolist())[0]

    max_sim = max(cos_sims)
    index_max = cos_sims.index(max_sim)
    print("(" + coded_words[i] + ", " + all_swedish_words[index_max] + ")" + " " + str(max_sim))
    paired_words.append((coded_words[i],all_swedish_words[index_max],max_sim))
# Out:
# (collaboration/program, sverige-kina) 1.0
# (defend, försvara) 0.6975184488828856
# (persistent, miljögifterna) 0.5773502691896258
# (agreement, överenskommelse) 0.39593773131515986
# (nurturing, byggnadsdesign) 0.4472135954999579
# (dominated, växthusdrivande) 0.4999999999999999
# (persistence, avmontering) 1.0
# (logic, gis) 0.4144268730094697
# (dependability, driftsäkerhet) 0.8362420100070908
# (supportive, gäster) 0.8498365855987976
# (co-operate, klass) 0.18257418583505533
# (shares, vindkraften) 0.7071067811865475
# (leadership, ledarskap) 0.45176266575807206
# (sharing, rawmatcop) 0.32444284226152503
# (cooperate, efterfrågad) 0.22633936510629632
# (courage, uppmuntra) 0.5343863402176421
# (collaboratively, industriparter) 0.5163977794943223
# (enthusiastically, hållbarare) 1.0
# (commitment, livscykelåtaganden) 0.4629100498862758
# (understandable, uppenbart) 0.7071067811865475
# (independently/individually, presentationsteknik) 0.7071067811865475
# (compete, kompe) 0.6389532301312268
# (competitiveness, it-service) 0.5773502691896258
# (leading, ledande) 0.7075897169118021
# (responsibility, ansvar) 0.3887788197375255
# (cooperating, fallproblematik) 0.4714045207910316
# (decides, tjänsteansökan) 0.7071067811865475
# (self-confident, trygg) 0.4999999999999999
# (cooperative, flygande) 0.48304589153964794
# (actively, aktivt) 0.48226637968187014
# (competitive, konkurrenskraft) 0.7537783614444091
# (superior, nvh-aspekter) 0.5
# (active, aktiv) 0.5539054720488445
# (leaderships, visas) 1.0
# (intellectual, intellektuella) 0.7715167498104597
# (collaborate, samarbeta) 0.48302556517503886
# (determined, tillämpar) 0.4082482904638631
# (connection, rekryteringsstöd) 0.42538497969766276
# (collaborations, samarbeten) 0.44172610429938614
# (yield, bearbetningsoperationer) 0.5773502691896258
# (dominating, förenklade) 1.0
# (children, skadehändelser) 0.7071067811865475
# (emotional, användarbehov) 0.816496580927726
# (sensitivity, va-branschen) 0.5773502691896258
# (dependent, självständig) 0.5696775863386776
# (challenges, utmaningar) 0.7717436331412897
# (responsi, ansvar) 0.5448508664289804
# (analyse, analyser) 0.35504716551814713
# (determining, dammbottnar) 0.6324555320336758
# (intellect, intellekt) 0.769800358919501
# (decision, beslut) 0.4580119625801939
# (enthusiastic, entusiastiska) 0.6454972243679029
# (collaborates, smes) 0.46829290579084704
# (dominates, universitetslektorer) 0.7071067811865475
# (objectives, målen) 0.4888237167378443
# (ambitious, ambitiös) 0.7878385971583355
# (kindly, längst) 0.408248290463863
# (collaborator, braham) 0.5
# (analyses, föroreningskällor) 0.31008683647302115
# (autonomy, autonomi) 0.5773502691896258
# (competences, labbresurser) 0.6123724356957945
# (cooperates, företagspartners) 0.5773502691896258
# (kinds, metod-) 0.3127716210856122
# (determination, projektorienterat) 0.5345224838248487
# (competition, definitivt) 0.5
# (understanding, förståelse) 0.69387442893233
# (defended, materialbearbetning) 0.7071067811865475
# (leaders, ledarskap) 0.392775231676896
# (depending, beroende) 0.4622367258209526
# (dependable, pålitlig) 0.6180254726923975
# (competencies, marknadsföringsområdet) 0.3333333333333333
# (collab-oration, affärsbehov) 0.35355339059327373
# (sensitive, känslig) 0.6963106238227914
# (challenged, teknologiperspektiv) 0.7071067811865475
# (challenging, utmanande) 0.6324555320336759
# (understand, förstå) 0.6834779925822734
# (committed, stadens) 0.6628489803598702
# (analysis, analys) 0.6611813047703956
# (autonomous, autonom) 0.5416138323063244
# (dependence, sökandens) 0.3779644730092272
# (decisive, policy-orienterad) 0.6324555320336758
# (feelings, psykologiska) 1.0
# (analysts, datatyper) 1.0
# (collaboration, samarbete) 0.47139790789635555
# (child, skadehändelser) 0.5
# (forces, drivkrafter) 0.9045340337332909
# (objective, mål) 0.3291469920372726
# (analytical, analytisk) 0.6222690382049305
# (commitments, livscykelåtaganden) 0.6123724356957945
# (analytics, analytics) 0.5855400437691199
# (agrees, ingredienserna) 1.0
# (support, stöd) 0.5961438883273091
# (agreements, tillkomma) 0.42640143271122083
# (objectively, swot-analys) 1.0
# (analyze, analysera) 0.4665694748158434
# (interpersonal, kognition) 0.23094010767585035
# (analytic, analytisk) 0.6355610640955788
# (force, drivkrafter) 0.4330127018922194
# (kind, typer) 0.2590095632952704
# (opinion, opinionsstudier) 0.8660254037844388
# (autonomously, forskarstudierna) 0.5773502691896258
# (together, tillsammans) 0.5651255925586891
# (responsible, ansvara) 0.47188350293088366
# (competing, biobränsleanvändning) 0.5773502691896258
# (trust, studie-) 0.4252260665667327
# (competency, urbanism) 0.816496580927726
# (determine, bestämma) 0.3913118960624632
# (analysing, sprida) 0.4472135954999579
# (analyzing, individuellt) 0.33333333333333337
# (inclusive, inkluderande) 1.0000000000000002
# (individuals, fou-centra) 0.43852900965351466
# (co-operatively, kooperativt) 0.7071067811865475
# (analyzes, kommersiellt) 0.408248290463863
# (cooperation, samarbete) 0.3226215166872094
# (ambition, ambition) 0.6998964726756152
# (individual, individ) 0.3536684159373046
# (responding, motsvara) 0.41046004583079343
# (determinants, bestämningsfaktorer) 0.7071067811865475
# (pleasant, trevlig) 1.0
# (dominant, ekonometri) 0.3042903097250923
# (competitions, definitivt) 1.0
# (connecting, fältkampanjer) 0.408248290463863
# (independency, snart) 0.4999999999999999
# (independence, sökandens) 0.4472135954999579
# (lead, leda) 0.6365258197395126
# (leader, ledarskap) 0.34522548160168254
# (individually, individuellt) 0.408248290463863
# (decisions, föroreningsbelastningen) 0.35355339059327373
# (committee, kommitte) 0.4714045207910316
# (collaborative, kollaborativ) 0.25819888974716115
# (responsibilities, uppgifter) 0.2410180678561366
# (connect, rekryteringsstöd) 0.3362963545672746
# (principles, principer) 0.8574929257125442
# (shared, samnyttjande) 0.5345224838248487
# (supported, stöds) 0.26892643710023856
# (share, vindkraften) 0.35355339059327373
# (connectivity, bristhabitat) 0.7071067811865475
# (hierarchical, hierarkisk) 0.8164965809277261
# (responibilities, konstruktionsteknik) 0.2672612419124244
# (response, respons) 0.5059644256269408
# (independently, självständigt) 0.5499623148376319
# (decision-making, beslutsprocesserna) 0.5
# (agreed, företrädarna) 0.31622776601683794
# (challeng-es, forestry) 1.0
# (respond, motsvara) 0.427725099232558
# (connected, sluten) 0.3405026123034995
# (principle, princip) 0.7151985398521515
# (co-operation, självständighet) 0.23947373603569988
# (decision-makers, samhällsorganisationer) 0.5773502691896258
# (competent, högklassiga) 0.4472135954999579
# (confident, trygg) 0.4714045207910316
# (collaborators, valideringsscheman) 0.5773502691896258
# (driven, driven) 0.5936420651095282
# (collaboration/, sverige-kina) 0.7071067811865475
# (cooperations, profilområden) 0.7071067811865475
# (trustworthy, hårda) 0.7071067811865475
# (warm, h2020-projektet) 0.6666666666666666
# (competence, kompetens) 0.6229573456455626
# (ambitions, ambitioner) 0.5773502691896258
# (analysed, reaktorerna) 0.3779644730092272
# (depends, vägbanan) 0.5345224838248487
# (leads, avslutas) 0.30000000000000004
# (analytically, arbetslaget) 1.0
# (independent, självständig) 0.5807238175924258
# (co-operations, lindholmen) 0.5773502691896258
# (analyzed, analyseras) 0.5276448530110864
# (feel, räknar) 0.3779644730092272
# (collaborating, rymdregion) 0.4211174438061578
# (decided, beslutas) 0.42640143271122083
# (depend, självständig) 0.5073859733325237
# (individual/passenger, trafiken) 0.7071067811865475
# (autonomic, riccardo) 0.7071067811865475
# (responses, responser) 0.4999999999999999
# (challenge, utmaning) 0.733224965999371
# (supporting, stötta) 0.29197858123689185
# (supports, produktiviteten) 0.42640143271122083
# (connections, förband) 0.4003203845127179

# %%
paired_words_docs = []

# Same as above, but using similarities over documents instead of sentences
for i in range (len(occurrence_matrix_docs)) :
    cos_sims = [cosine_similarity([occurrence_matrix_docs[i]],occurrence_matrix_docs_sv)] 
  
    cos_sims = (cos_sims[0].tolist())[0]

    max_sim = max(cos_sims)
    index_max = cos_sims.index(max_sim)
    print("(" + coded_words[i] + ", " + all_swedish_words[index_max] + ")" + " " + str(max_sim))
    paired_words_docs.append((coded_words[i],all_swedish_words[index_max],max_sim))
# Out:
# (collaboration/program, mpc) 1.0
# (defend, försvara) 0.8641264122753545
# (persistent, oföränderlig) 0.816496580927726
# (agreement, överenskommelse) 0.5060243137049899
# (nurturing, bostadssituation) 1.0
# (dominated, växthusdrivande) 0.5345224838248487
# (persistence, avmontering) 1.0
# (logic, geologisk) 0.6888051864876661
# (dependability, driftsäkerhet) 0.819891591749923
# (supportive, gäster) 0.8823529411764706
# (co-operate, spann) 0.9999999999999998
# (shares, fsi) 1.0
# (leadership, ledarskap) 0.5763708787148328
# (sharing, utvecklingsmiljöer) 0.6396021490668313
# (cooperate, planerad) 0.3373495424699933
# (courage, uppmuntra) 0.645709524069209
# (collaboratively, laser-icp) 0.5773502691896258
# (enthusiastically, yrkesperson) 1.0
# (commitment, livscykelåtaganden) 0.6201736729460423
# (understandable, licentiand) 1.0
# (independently/individually, hybridfordon) 1.0
# (compete, kompe) 0.6700328973383107
# (competitiveness, examinerats) 0.5773502691896258
# (leading, ledande) 0.8178668406284002
# (responsibility, ansvar) 0.7937897920748735
# (cooperating, svaj) 0.6396021490668312
# (decides, 20160510) 1.0
# (self-confident, prefektrekryteringar) 1.0
# (cooperative, 6d) 0.8257228238447705
# (actively, aktivt) 0.7634086134992224
# (competitive, konkurrenskraft) 0.7130240959073808
# (superior, spann) 0.6324555320336758
# (active, aktiv) 0.8439964815934364
# (leaderships, forskargruppsledare) 1.0
# (intellectual, bestämningsfaktorer) 0.9128709291752769
# (collaborate, samarbeta) 0.5663037824159948
# (determined, tillbaka) 0.777777777777778
# (connection, band) 0.4556611884328835
# (collaborations, samarbeten) 0.6865192821998627
# (yield, biokoksutbytet) 0.5773502691896258
# (dominating, vintertestanläggningar) 1.0
# (children, uppfattar) 0.5773502691896258
# (emotional, emotionell) 1.0
# (sensitivity, känslighets-) 0.8660254037844388
# (dependent, självständig) 0.8223426931577976
# (challenges, utmaningar) 0.83883724585492
# (responsi, ansvar) 0.8488409825076472
# (analyse, vegetation) 0.5696519211398116
# (determining, fastläggs) 0.6324555320336758
# (intellect, intellekt) 0.9049228966693287
# (decision, beslutsstöd) 0.6488662961696022
# (enthusiastic, entusiastiska) 0.6804138174397717
# (collaborates, policyskapare) 0.6390096504226936
# (dominates, databashantering) 0.5773502691896258
# (objectives, målen) 0.42884501393511787
# (ambitious, ambitiös) 0.791666666666667
# (kindly, licentiand) 0.7071067811865475
# (collaborator, nvh-aspekter) 0.5773502691896258
# (analyses, vegetation) 0.6000000000000001
# (autonomy, autonomi) 0.7216878364870323
# (competences, labbresurser) 0.6123724356957945
# (cooperates, dmk) 0.8728715609439696
# (kinds, blockkedjor) 0.39999999999999997
# (determination, bestämning) 0.8999999999999999
# (competition, beslutsproblem) 0.5
# (understanding, förståelse) 0.8021656411984014
# (defended, diffraktiva) 1.0
# (leaders, ledarskap) 0.5482482140415199
# (depending, beroende) 0.5312127152597306
# (dependable, nätverksarkitekturer) 0.8952858934153914
# (competencies, fortbildning) 0.39223227027636803
# (collab-oration, seminarieaktiviteter) 1.0
# (sensitive, känslig) 0.6405126152203486
# (challenged, rymdanknutna) 0.9999999999999998
# (challenging, utmanande) 0.816496580927726
# (understand, förstå) 0.8535960818856789
# (committed, dricks-) 0.7983723279170813
# (analysis, analys) 0.8394391923607594
# (autonomous, autonom) 0.718325463293173
# (dependence, bildanalysalgoritmer) 0.3779644730092272
# (decisive, policy-orienterad) 0.8451542547285166
# (feelings, känslor) 1.0
# (analysts, datarika) 1.0
# (collaboration, am) 0.7237184332733817
# (child, artificiella) 0.5773502691896258
# (forces, drivkrafter) 0.8528028654224418
# (objective, mål) 0.46637145496980625
# (analytical, analytisk) 0.8294242967454114
# (commitments, livscykelåtaganden) 0.912870929175277
# (analytics, analytics) 0.6429100507328636
# (agrees, revolutionerande) 1.0
# (support, stöd) 0.8066130174532531
# (agreements, överenskommelser) 0.5640760748177661
# (objectively, swot-analys) 1.0
# (analyze, analysera) 0.5249081491101555
# (interpersonal, personell) 0.5516772843673704
# (analytic, analytisk) 0.8000101009463328
# (force, kompositmaterial) 0.4569930283497495
# (kind, blockkedjor) 0.3113995776646092
# (opinion, opinionsstudier) 1.0
# (autonomously, fysikliska) 1.0
# (together, tillsammans) 0.7176592762704421
# (responsible, ansvara) 0.6610820453902343
# (competing, biobränsleanvändning) 0.5773502691896258
# (trust, tillit) 0.8224396186997104
# (competency, övervinner) 0.9999999999999998
# (determine, tillbaka) 0.5217491947499511
# (analysing, rymdfarkostdata) 0.4472135954999579
# (analyzing, produktionslösningar) 0.46524210519923537
# (inclusive, fysiologiska) 0.8488746876271656
# (individuals, opinionsstudier) 0.44194173824159216
# (co-operatively, silesian) 1.0
# (analyzes, prototyputveckling) 0.7071067811865475
# (cooperation, samarbete) 0.653841920540054
# (ambition, ambition) 0.8484848484848486
# (individual, individ) 0.6062019963443338
# (responding, utvec) 0.43091314761744437
# (determinants, bestämningsfaktorer) 1.0
# (pleasant, motor-) 1.0
# (dominant, ekonometriker) 0.5345224838248488
# (competitions, energiförsörjningen) 1.0
# (connecting, atmosfärsfenomen) 1.0
# (independency, företagsbesök) 0.816496580927726
# (independence, bildanalysalgoritmer) 0.4472135954999579
# (lead, leda) 0.8208683010653286
# (leader, led) 0.5445870705571825
# (individually, produktionslösningar) 0.48795003647426655
# (decisions, handläggning) 0.5144957554275265
# (committee, 20160510) 0.8980265101338746
# (collaborative, kollaborativ) 0.6228789144581013
# (responsibilities, undervisning) 0.39610141494500084
# (connect, mer) 0.4085282017464542
# (principles, principer) 0.8858795678282981
# (shared, nyckelperson) 0.5773502691896258
# (supported, naturresurser) 0.3272755214544647
# (share, nyckelperson) 0.36514837167011066
# (connectivity, miljöförbättrande) 0.7071067811865475
# (hierarchical, hierarkisk) 0.801783725737273
# (responibilities, konstruktionsprocessen) 1.0
# (response, respons) 0.4654746681256313
# (independently, självständigt) 0.7891627813735065
# (decision-making, eunderhåll) 0.8164965809277261
# (agreed, sekvensering) 0.50709255283711
# (challeng-es, seminarieaktiviteter) 1.0
# (respond, visa) 0.5029642433257904
# (connected, radioaccess) 0.32274861218395146
# (principle, princip) 0.7356123579206246
# (co-operation, termomekaniska) 0.5031152949374527
# (decision-makers, kartografisk) 0.7071067811865475
# (competent, materialoptimering) 0.7071067811865475
# (confident, prefektrekryteringar) 0.8944271909999159
# (collaborators, biokoksutbytet) 0.7071067811865475
# (driven, driven) 0.6797646651599362
# (collaboration/, mpc) 0.7071067811865475
# (cooperations, värdskapet) 0.5773502691896258
# (trustworthy, säkerhetsmekanismer) 0.7071067811865475
# (warm, h2020-projektet) 0.8320502943378437
# (competence, kompetens) 0.6533653813103308
# (ambitions, framdriften) 0.816496580927726
# (analysed, kompetensförsörjningen) 0.6396021490668312
# (depends, amminex) 0.4472135954999579
# (leads, elektronstrukturberäkningar) 0.3611575592573077
# (analytically, h2020-projektet) 0.7071067811865475
# (independent, självständig) 0.8326604511181981
# (co-operations, spann) 0.816496580927726
# (analyzed, dataintegration) 0.5547001962252291
# (feel, inhämtat) 0.6324555320336758
# (collaborating, bostadssituation) 0.3651483716701107
# (decided, beslutas) 0.45226701686664544
# (depend, självständig) 0.6675875326149425
# (individual/passenger, moped) 1.0
# (autonomic, mjukvaruutvecklingsgrupperna) 1.0
# (responses, responser) 0.8660254037844388
# (challenge, utmaning) 0.829159361262666
# (supporting, stötta) 0.5323891012560911
# (supports, produktiviteten) 0.4472135954999579
# (connections, vindturbiner) 0.5773502691896258
